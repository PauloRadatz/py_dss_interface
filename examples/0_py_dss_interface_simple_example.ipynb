# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloRadatz/py_dss_interface/blob/master/examples/0_py_dss_interface_simple_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using OpenDSS Linux Version via py-dss-interface in Google Colab
#
# `py-dss-interface` versions after 2.3.0 include a pre-built Linux version of OpenDSS, so you do not need to build OpenDSS each time you use Google Colab. This makes it ready to use for a classroom lesson right away.

# %%
# !git clone https://github.com/PauloRadatz/opendss-python-examples
# !pip install py-dss-interface
# Out:
# Cloning into 'opendss-python-examples'...
# remote: Enumerating objects: 88, done.
# remote: Counting objects: 100% (88/88), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 88 (delta 27), reused 49 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (88/88), 313.89 KiB | 7.85 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# ...

# %%
import py_dss_interface
dss = py_dss_interface.DSS()
dss_file_path = "/content/opendss-python-examples/feeder_models/EPRITestCircuits/ckt5/Master_ckt5.dss"
dss.text("clear")
dss.text(f'compile "{dss_file_path}"')
dss.text("solve")
# Out:
# ''

# %%
dss.circuit.total_power
# Out:
# [-7281.249069587565, -3584.320417152697]
